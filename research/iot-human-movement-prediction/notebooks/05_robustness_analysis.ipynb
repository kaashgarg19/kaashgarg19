# %% [markdown]
# # 05 — Robustness analysis
#
# This notebook is the entry point for the completed extension experiments: unseen-device evaluation, feature ablation, threshold sensitivity and uncertainty. Canonical CSV outputs are documented in `docs/experimental_protocol.md` and `PYTHON_CODEBOOK_v2.md`.

# %%
from pathlib import Path
import pandas as pd
RESULTS = Path('../results')

# %% [markdown]
# ## 1. Canonical artifacts
#
# Place the verified canonical CSV files in `results/` when they are ready to be committed. Expected files include:
#
# - `MASTER_RANDOM_VS_TEMPORAL_RESULTS.csv`
# - `TEMPORAL_MODEL_RESULTS.csv`
# - `UNSEEN_DEVICE_RESULTS.csv`
# - `FEATURE_ABLATION_RESULTS.csv`
# - `THRESHOLD_SENSITIVITY_RESULTS.csv`
# - `TEMPORAL_RECALL_UNCERTAINTY.csv`
# - `TEMPORAL_PR_CURVES.csv`
# - `TEMPORAL_CALIBRATION.csv`
# - `TEMPORAL_THRESHOLD_SNAPSHOTS.csv`
# - `MASTER_EXPERIMENT_INDEX.csv`

# %%
for path in sorted(RESULTS.glob('*.csv')):
    print(path.name)

# %% [markdown]
# ## 2. Interpretation rules
#
# Do not replace canonical results with later conflicting reruns. In particular, the audited research record excludes `FINAL_TEMPORAL_AUDIT_RESULTS.csv` because a later Random Forest configuration produced conflicting results.
#
# Feature importance is predictive evidence, not causal evidence. Device-level results are preliminary because only three devices are available. AP confidence intervals were not completed and must not be claimed.
